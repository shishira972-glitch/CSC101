# %% [markdown]
# <a href="https://colab.research.google.com/github/shishira972-glitch/CSC101/blob/main/week8_project_spec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c0b52e1b-1c85-4988-917e-81886b50d70a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0b52e1b-1c85-4988-917e-81886b50d70a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def load_transactions(filename):
    try:
        with open(filename, 'r') as file:
            lines = file.readlines()
        return [line.strip() for line in lines if line.strip()]
    except FileNotFoundError:
        print(f"File '{filename}' not found!")
        return []

def process_transactions(lines):
    transactions = []
    failed = 0

    for line in lines:
        try:
            parts = line.split(',')
            if len(parts) != 2:
                raise ValueError

            description = parts[0]
            amount = float(parts[1])

            transactions.append({'description': description, 'amount': amount})

        except:
            print('Skipped bad line:', line)
            failed += 1

    print('\nBad lines skipped:', failed)
    return transactions

def show_summary(transactions):
    income = 0
    expenses = 0

    for t in transactions:
        if t['amount'] > 0:
            income += t['amount']
        else:
            expenses += t['amount']

    print('\n=== SUMMARY ===')
    print('Total transactions:', len(transactions))
    print('Total income:', income)
    print('Total expenses:', expenses)
    print('Net amount:', income + expenses)

lines = load_transactions('transactions.txt')
transactions = process_transactions(lines)
show_summary(transactions)
# Out:
# Skipped bad line: BAD LINE HERE
#
# Bad lines skipped: 1
#
# === SUMMARY ===
# Total transactions: 6
# Total income: 1535.5
# Total expenses: -155.89
# Net amount: 1379.6100000000001

# %% [markdown]
# Reflection
#
# The most difficult part of this assignment was making sure the program did not stop or crash when it found incorrect or messy data in the file, such as missing commas or wrong values. In the beginning, I was not sure how to deal with these types of errors.
#
# I used AI to learn how to apply try and except so the program could skip invalid lines and continue running smoothly. AI also guided me in breaking the program into smaller functions, like reading the file, handling the data, and displaying the output. This made the program easier to understand and debug.
